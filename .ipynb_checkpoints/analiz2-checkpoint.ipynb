# %%
import pandas as pd

# Veri setini tekrar yükleyelim
file_path = r"C:\Users\90551\Desktop\gearbox2\Interpolated_and_Predicted_Data.xlsx"
df = pd.read_excel(file_path)

# Zaman sütununu datetime formatına çevirelim
df['time'] = pd.to_datetime(df['time'])

# Gearbox sıcaklık sensörleri ve ortam sıcaklığı değişkenleri
temp_columns = [
    'BRS.T35_T_GBX_OIL_1', 'BRS.T35_T_GBX_OIL_2',
    'BRS.T35_T_GBX_T1_HSS', 'BRS.T35_T_GBX_T1_IMS',
    'BRS.T35_T_GBX_T3_HSS', 'BRS.T35_T_GBX_T3_IMS',
    'BRS.T35_T_GEAR_BEAR'
]

# Ortam sıcaklığı
ambient_temp = 'BRS.T35_Temp_Ambient'

# 1. Tüm sıcaklık değerlerinden ortam sıcaklığını çıkartarak farklarını alalım
df_temp_differences = df[temp_columns].sub(df[ambient_temp], axis=0)

# 2. Bu farkları toplayıp ortalamasını alalım
df['temp_diff_avg'] = df_temp_differences.mean(axis=1)

# 3. Bu ortalamayı rotor hızına (BRS.T35_N_ROT_PLC) bölelim
df['temp_diff_per_rpm'] = df['temp_diff_avg'] / df['BRS.T35_N_ROT_PLC']

df.head()
# Out:
#                  time  BRS.T35_N_ROT_PLC  BRS.T35_Power  BRS.T35_T_GBX_OIL_1  \
# 0 2024-01-25 00:00:00          10.723178     544.650024            55.150002
# 1 2024-01-25 00:10:00          10.255564     420.470001            54.810001
# 2 2024-01-25 00:20:00          10.076803     404.429993            54.480000
# 3 2024-01-25 00:30:00           9.851302     344.700012            54.139999
# 4 2024-01-25 00:40:00           9.354575     157.369995            53.799999
#
#    BRS.T35_T_GBX_OIL_2  BRS.T35_T_GBX_T1_HSS  BRS.T35_T_GBX_T1_IMS  \
# 0            58.610001             56.509998             52.779999
# 1            57.990002             56.080002             52.410000
# 2            57.490002             55.650002             52.029999
# 3            56.980000             55.209999             51.660000
# 4            56.470001             54.779999             51.279999
#
#    BRS.T35_T_GBX_T3_HSS  BRS.T35_T_GBX_T3_IMS  BRS.T35_T_GEAR_BEAR  \
# ...

# %%
import matplotlib.pyplot as plt
# Grafik oluşturma
# Grafik oluşturma
plt.figure(figsize=(12, 6))
plt.plot(df["time"], df["temp_diff_per_rpm"], linestyle='-', marker='o', color='b', label="Temp Diff per RPM")

# Grafik düzenlemeleri
plt.xlabel("Zaman")
plt.ylabel("Temp Diff per RPM")
plt.title("Temp Diff per RPM Zaman Serisi Grafiği")
plt.xticks(rotation=45)
plt.legend()
plt.grid()

# Grafiği gösterme
plt.show()

# %%
# Sonuçları kullanıcıya gösterelim
import ace_tools as tools
tools.display_dataframe_to_user(name="Gearbox Sıcaklık Analizi", dataframe=df[['time', 'temp_diff_avg', 'temp_diff_per_rpm']])

# %%
import pandas as pd

# Veri setini yükleme
file_path = "Interpolated_and_Predicted_Data.xlsx"  # Dosya yolunu güncelleyin
df = pd.read_excel(file_path)

# Zaman sütununu datetime formatına çevirme
df['time'] = pd.to_datetime(df['time'])

# 2 saatlik aralıklara göre yeniden örnekleme yapma
df_resampled = df.resample('60T', on='time').agg({
    'BRS.T35_N_ROT_PLC': 'mean',  # Ortalama rotor hızı
    'BRS.T35_Power': 'sum',  # Toplam üretilen güç
    'BRS.T35_T_GBX_OIL_1': 'mean',  # Ortalama gearbox yağı sıcaklığı
    'BRS.T35_T_GBX_OIL_2': 'mean',
    'BRS.T35_T_GBX_T1_HSS': 'mean',
    'BRS.T35_T_GBX_T1_IMS': 'mean',
    'BRS.T35_T_GBX_T3_HSS': 'mean',
    'BRS.T35_T_GBX_T3_IMS': 'mean',
    'BRS.T35_T_GEAR_BEAR': 'mean',
    'BRS.T35_Temp_Ambient': 'mean',  # Ortalama ortam sıcaklığı
    'BRS.T35_WIND_DIR': 'mean',  # Ortalama rüzgar yönü
    'BRS.T35_Wind_speed': 'mean'  # Ortalama rüzgar hızı
})
# Out:
# C:\Users\90551\AppData\Local\Temp\ipykernel_16016\2627575937.py:11: FutureWarning: 'T' is deprecated and will be removed in a future version, please use 'min' instead.
#   df_resampled = df.resample('60T', on='time').agg({

# %%
df.head(20)
# Out:
#                   time  BRS.T35_N_ROT_PLC  BRS.T35_Power  BRS.T35_T_GBX_OIL_1  \
# 0  2024-01-25 00:00:00          10.723178     544.650024            55.150002
# 1  2024-01-25 00:10:00          10.255564     420.470001            54.810001
# 2  2024-01-25 00:20:00          10.076803     404.429993            54.480000
# 3  2024-01-25 00:30:00           9.851302     344.700012            54.139999
# 4  2024-01-25 00:40:00           9.354575     157.369995            53.799999
# 5  2024-01-25 00:50:00           9.167848     260.380005            53.470001
# 6  2024-01-25 01:00:00           9.211395     520.030029            53.130001
# 7  2024-01-25 01:10:00           8.950231     372.510010            52.790001
# 8  2024-01-25 01:20:00           8.681541     407.929993            52.459999
# 9  2024-01-25 01:30:00           8.551056     373.100006            52.119999
# 10 2024-01-25 01:40:00           8.340015     285.890015            51.779999
# ...

# %%
df.min()
# Out:
# time                    2024-01-25 00:00:00
# BRS.T35_N_ROT_PLC                 -3.481128
# BRS.T35_Power                   -387.119995
# BRS.T35_T_GBX_OIL_1                     0.0
# BRS.T35_T_GBX_OIL_2                     0.0
# BRS.T35_T_GBX_T1_HSS                    0.0
# BRS.T35_T_GBX_T1_IMS                    0.0
# BRS.T35_T_GBX_T3_HSS                    0.0
# BRS.T35_T_GBX_T3_IMS                    0.0
# BRS.T35_T_GEAR_BEAR                     0.0
# BRS.T35_Temp_Ambient                   -3.0
# BRS.T35_WIND_DIR                     -139.0
# BRS.T35_Wind_speed                      0.0
# dtype: object

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 📌 1. VERİYİ YÜKLE
file_path = "‪Interpolated_and_Predicted_Data.csv"  # Dosyanın adını gerektiği gibi değiştir
df = pd.read_csv("Interpolated_and_Predicted_Data.csv")

# 📌 2. TEMEL BİLGİLERİ İNCELE
print("🔹 İlk 5 Satır:\n", df.head())
print("\n🔹 Veri Bilgisi:\n")
df.info()
print("\n🔹 İstatistiksel Özet:\n", df.describe())

# 📌 3. EKSİK VERİLERİ GÖSTER
print("\n🔹 Eksik Veri Sayısı:\n", df.isna().sum())

# 📌 4. GÖRSELLEŞTİRME
plt.figure(figsize=(10, 6))
sns.histplot(df.select_dtypes(include=['float64', 'int64']), bins=30, kde=True)
plt.title("📊 Sayısal Değişkenlerin Dağılımı")
plt.show()
# Out:
# 🔹 İlk 5 Satır:
#                    time  BRS.T35_N_ROT_PLC  BRS.T35_Power  BRS.T35_T_GBX_OIL_1  \
# 0  2024-01-25 00:00:00          10.723178     544.650024            55.150002
# 1  2024-01-25 00:10:00          10.255564     420.470001            54.810001
# 2  2024-01-25 00:20:00          10.076803     404.429993            54.480000
# 3  2024-01-25 00:30:00           9.851302     344.700012            54.139999
# 4  2024-01-25 00:40:00           9.354575     157.369995            53.799999
#
#    BRS.T35_T_GBX_OIL_2  BRS.T35_T_GBX_T1_HSS  BRS.T35_T_GBX_T1_IMS  \
# 0            58.610001             56.509998             52.779999
# 1            57.990002             56.080002             52.410000
# 2            57.490002             55.650002             52.029999
# 3            56.980000             55.209999             51.660000
# 4            56.470001             54.779999             51.279999
#
#    BRS.T35_T_GBX_T3_HSS  BRS.T35_T_GBX_T3_IMS  BRS.T35_T_GEAR_BEAR  \
# ...

# %%
import pandas as pd

# Sabit değerler
AIR_DENSITY = 1.225  # kg/m³ (hava yoğunluğu)
SWEPT_AREA = 8_332.0  # m² (rüzgar türbininin süpürdüğü alan)
POWER_COEFFICIENT = 0.237  # GE Vernova GE 2.75-103 için hesaplanan Cp değeri
CONSTANT = 0.5  # Formülde sabit

# Teorik güç hesaplama fonksiyonu
def calculate_theoretical_power(v):
    """
    GE Vernova GE 2.75-103 modeline göre rüzgar hızına bağlı teorik güç hesaplar.
    Formül: P = (1/2) * ρ * A * Cp * v^3
    """
    return (CONSTANT * AIR_DENSITY * SWEPT_AREA * POWER_COEFFICIENT * (v ** 3))/1000

# Veri setini yükle
file_path = "Interpolated_and_Predicted_Data.xlsx"  # Dosya yolunu güncelleyin
df = pd.read_excel(file_path)

# Datasete yeni bir kolon olarak teorik gücü ekleyelim
df['theoretical_power_ge'] = df['BRS.T35_Wind_speed'].apply(calculate_theoretical_power)

# %%
import pandas as pd
import numpy as np

# Sabit değerler
AIR_DENSITY = 1.225  # kg/m³ (hava yoğunluğu)
ROTOR_DIAMETER = 103.5  # metre (rotor çapı)
SWEPT_AREA = np.pi * (ROTOR_DIAMETER / 2) ** 2  # m² (süpürülen alan)
POWER_COEFFICIENT = 0.4  # Güç katsayısı (Cp)
CONSTANT = 0.5  # Formülde sabit

# Teorik güç hesaplama fonksiyonu
def calculate_theoretical_power(v):
    """
    Rüzgâr hızına bağlı teorik güç hesaplar.
    Formül: P = (1/2) * ρ * A * Cp * v^3
    """
    return (CONSTANT * AIR_DENSITY * SWEPT_AREA * POWER_COEFFICIENT * (v ** 3))*0.001


# Datasete yeni bir kolon olarak teorik gücü ekleyelim
df['theoretical_power_bares'] = df['BRS.T35_Wind_speed'].apply(calculate_theoretical_power)

# %%
import pandas as pd
import numpy as np

# Sabit değerler
AIR_DENSITY = 1.225  # kg/m³ (hava yoğunluğu)
ROTOR_DIAMETER = 103.0  # metre (doğru rotor çapı)
SWEPT_AREA = np.pi * (ROTOR_DIAMETER / 2) ** 2  # m² (süpürülen alan)
POWER_COEFFICIENT = 0.237  # GE Vernova 2.75-103 için hesaplanan Cp değeri
CONSTANT = 0.5  # Formülde sabit

# Teorik güç hesaplama fonksiyonu
def calculate_theoretical_power(v):
    """
    GE Vernova GE 2.75-103 modeline göre rüzgar hızına bağlı teorik güç hesaplar.
    Formül: P = (1/2) * ρ * A * Cp * v^3
    """
    return CONSTANT * AIR_DENSITY * SWEPT_AREA * POWER_COEFFICIENT * (v ** 3)

# Veri setini yükle
file_path = "Interpolated_and_Predicted_Data.xlsx"  # Dosya yolunu güncelleyin
df = pd.read_excel(file_path)

# Datasete yeni bir kolon olarak teorik gücü ekleyelim
df['theoretical_power_ge'] = df['BRS.T35_Wind_speed'].apply(calculate_theoretical_power)

# Güncellenmiş veri setini kaydet
df.to_excel("Interpolated_and_Predicted_Data_with_Corrected_Theoretical_Power.xlsx", index=False)

# %%
df.max()
# Out:
# time                       2025-02-23 23:50:00
# BRS.T35_N_ROT_PLC                    17.435852
# BRS.T35_Power                      2857.959961
# BRS.T35_T_GBX_OIL_1                       72.0
# BRS.T35_T_GBX_OIL_2                  75.860001
# BRS.T35_T_GBX_T1_HSS                 75.830002
# BRS.T35_T_GBX_T1_IMS                      71.0
# BRS.T35_T_GBX_T3_HSS                 78.790001
# BRS.T35_T_GBX_T3_IMS                 74.870003
# BRS.T35_T_GEAR_BEAR                  78.790001
# BRS.T35_Temp_Ambient                     39.91
# BRS.T35_WIND_DIR                         515.0
# BRS.T35_Wind_speed                       21.42
# theoretical_power_bares           20257.930165
# dtype: object

# %%
df.to_excel("Interpolated_and_Predicted_Data_with_GE_Theoretical_Power.xlsx", index=False)

# %%
# 📌 5. ZAMAN SERİSİ ANALİZİ (Örnek: Güç & Rüzgar Hızı)
plt.figure(figsize=(12, 6))
plt.plot(df['time'], df['BRS.T35_Power'], label='Power (kW)', color='blue')
plt.plot(df['time'], df['BRS.T35_Wind_speed'], label='Wind Speed (m/s)', color='green')
plt.xlabel("Time")
plt.ylabel("Value")
plt.title("🔄 Güç ve Rüzgar Hızının Zaman İçinde Değişimi")
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\90551\anaconda3\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128260 (\N{ANTICLOCKWISE DOWNWARDS AND UPWARDS OPEN CIRCLE ARROWS}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 📌 6. KORELASYON MATRİSİ
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("📌 Korelasyon Matrisi")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 3
#       1 # 📌 6. KORELASYON MATRİSİ
#       2 plt.figure(figsize=(10, 8))
# ----> 3 sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
#       4 plt.title("📌 Korelasyon Matrisi")
#       5 plt.show()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
# Gerekli kütüphaneleri içe aktarma
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# CSV dosyasını yükleme (dosya adını kendi dosyanla değiştir)
file_path = "Interpolated_and_Predicted_Data.csv"
df = pd.read_csv(file_path)

# "time" sütununu datetime formatına çevirme
df["time"] = pd.to_datetime(df["time"])

# Sayısal sütunları seçme
numeric_cols = df.select_dtypes(include=["float64", "int64"]).columns

# Grafiklerin şık görünmesi için stil ayarı
sns.set_style("whitegrid")

# Her sayısal kolonu zamana göre çizdirme
for col in numeric_cols:
    plt.figure(figsize=(12, 5))
    sns.lineplot(data=df, x="time", y=col, label=col, color='b')
    plt.title(f"Zamana Göre {col} Değişimi")
    plt.xlabel("Zaman")
    plt.ylabel(col)
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Korelasyon matrisi
plt.figure(figsize=(12, 8))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)
plt.title("Korelasyon Matrisi")
plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[col], kde=True, bins=30)
    plt.title(f"{col} Dağılımı")
    plt.xlabel(col)
    plt.show()

# %%
for col in numeric_cols:
    plt.figure(figsize=(6, 4))
    sns.boxplot(x=df[col])
    plt.title(f"{col} Boxplot (Aykırı Değerler)")
    plt.show()

# %%
window_size = 5  # Ortalama alınacak pencere boyutu

for col in numeric_cols:
    df[f"{col}_ma"] = df[col].rolling(window=window_size).mean()

    plt.figure(figsize=(12, 5))
    plt.plot(df["time"], df[col], label=f"{col} (Orijinal)", alpha=0.5)
    plt.plot(df["time"], df[f"{col}_ma"], label=f"{col} (MA {window_size})", color='red')
    plt.title(f"Zamana Göre {col} (Hareketli Ortalama ile)")
    plt.xlabel("Zaman")
    plt.ylabel(col)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Veriyi standardize etme
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df[numeric_cols])

# K-Means Modeli
kmeans = KMeans(n_clusters=3, random_state=42, n_init=10)  # 3 farklı durum varsayıyoruz
df["Health_State"] = kmeans.fit_predict(df_scaled)

# Yeni sağlık durumlarını görselleştirme
plt.figure(figsize=(12, 6))
sns.scatterplot(x=df["time"], y=df[numeric_cols[0]], hue=df["Health_State"], palette="viridis")
plt.title("Makine Sağlık Durumu - K-Means Kümeleme")
plt.xlabel("Zaman")
plt.ylabel(numeric_cols[0])
plt.legend(title="Health State")
plt.show()

# %%
def detect_outliers(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    return outliers

for col in numeric_cols:
    outliers = detect_outliers(df, col)
    print(f"{col} Kolonunda {len(outliers)} Aykırı Değer Bulundu")
# Out:
# BRS.T35_N_ROT_PLC Kolonunda 0 Aykırı Değer Bulundu
# BRS.T35_Power Kolonunda 0 Aykırı Değer Bulundu
# BRS.T35_T_GBX_OIL_1 Kolonunda 381 Aykırı Değer Bulundu
# BRS.T35_T_GBX_OIL_2 Kolonunda 35 Aykırı Değer Bulundu
# BRS.T35_T_GBX_T1_HSS Kolonunda 6 Aykırı Değer Bulundu
# BRS.T35_T_GBX_T1_IMS Kolonunda 117 Aykırı Değer Bulundu
# BRS.T35_T_GBX_T3_HSS Kolonunda 6 Aykırı Değer Bulundu
# BRS.T35_T_GBX_T3_IMS Kolonunda 372 Aykırı Değer Bulundu
# BRS.T35_T_GEAR_BEAR Kolonunda 6 Aykırı Değer Bulundu
# BRS.T35_Temp_Ambient Kolonunda 0 Aykırı Değer Bulundu
# BRS.T35_WIND_DIR Kolonunda 45 Aykırı Değer Bulundu
# BRS.T35_Wind_speed Kolonunda 100 Aykırı Değer Bulundu

# %%
import matplotlib.pyplot as plt

# Hareketli ortalama hesaplama (pürüzsüz veri seti oluşturma)
window_size = 5  # Ortalama alınacak pencere boyutu

# Grafik çizimi
for col in numeric_cols:
    df[f"{col}_ma"] = df[col].rolling(window=window_size).mean()  # Hareketli ortalama hesapla

    plt.figure(figsize=(12, 5))
    plt.plot(df["time"], df[f"{col}_ma"], label=f"{col} (MA {window_size})", color='red')  # Sadece pürüzsüz veri
    plt.title(f"Zamana Göre {col} (Pürüzsüz Hareketli Ortalama)")
    plt.xlabel("Zaman")
    plt.ylabel(col)
    plt.legend()
    plt.grid(True)
    plt.show()
