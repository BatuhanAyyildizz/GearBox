# %%
from sklearn.model_selection import train_test_split
from lightgbm import LGBMRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Define features and target
target_column = "BRS.T35_T_GBX_Avg"
features = df.drop(columns=["time", target_column])  # Drop time and target column
target = df[target_column]

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size=0.2, random_state=42)

# Train LightGBM model
lgb_model = LGBMRegressor()
lgb_model.fit(X_train, y_train)

# Make predictions
y_pred = lgb_model.predict(X_test)

# Evaluate model
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = mse ** 0.5
r2 = r2_score(y_test, y_pred)

# Display evaluation metrics
mae, rmse, r2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       5 # Define features and target
#       6 target_column = "BRS.T35_T_GBX_Avg"
# ----> 7 features = df.drop(columns=["time", target_column])  # Drop time and target column
#       8 target = df[target_column]
#      10 # Split data into train and test sets
#
# NameError: name 'df' is not defined

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-4.6.0-py3-none-win_amd64.whl.metadata (17 kB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\90551\anaconda3\lib\site-packages (from lightgbm) (1.26.4)
# Requirement already satisfied: scipy in c:\users\90551\anaconda3\lib\site-packages (from lightgbm) (1.13.1)
# Downloading lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#     --------------------------------------- 0.0/1.5 MB 660.6 kB/s eta 0:00:03
#     --------------------------------------- 0.0/1.5 MB 660.6 kB/s eta 0:00:03
#    - -------------------------------------- 0.0/1.5 MB 330.3 kB/s eta 0:00:05
#    - -------------------------------------- 0.1/1.5 MB 393.8 kB/s eta 0:00:04
#    -- ------------------------------------- 0.1/1.5 MB 438.1 kB/s eta 0:00:04
#    --- ------------------------------------ 0.1/1.5 MB 469.7 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.5 MB 510.2 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.2/1.5 MB 510.2 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.5 MB 513.4 kB/s eta 0:00:03
#    ----- ---------------------------------- 0.2/1.5 MB 498.9 kB/s eta 0:00:03
#    ------ --------------------------------- 0.2/1.5 MB 497.3 kB/s eta 0:00:03
#    ------- -------------------------------- 0.3/1.5 MB 550.1 kB/s eta 0:00:03
#    ------- -------------------------------- 0.3/1.5 MB 550.1 kB/s eta 0:00:03
#    --------- ------------------------------ 0.3/1.5 MB 566.9 kB/s eta 0:00:02
#    --------- ------------------------------ 0.3/1.5 MB 566.9 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.4/1.5 MB 560.0 kB/s eta 0:00:02
#    ---------- ----------------------------- 0.4/1.5 MB 551.5 kB/s eta 0:00:02
#    ------------ --------------------------- 0.4/1.5 MB 585.9 kB/s eta 0:00:02
#    ------------ --------------------------- 0.5/1.5 MB 575.6 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.5 MB 568.9 kB/s eta 0:00:02
#    ------------- -------------------------- 0.5/1.5 MB 568.9 kB/s eta 0:00:02
#    --------------- ------------------------ 0.6/1.5 MB 599.0 kB/s eta 0:00:02
#    --------------- ------------------------ 0.6/1.5 MB 590.1 kB/s eta 0:00:02
#    ---------------- ----------------------- 0.6/1.5 MB 604.2 kB/s eta 0:00:02
#    ----------------- ---------------------- 0.6/1.5 MB 625.5 kB/s eta 0:00:02
#    ------------------ --------------------- 0.7/1.5 MB 617.1 kB/s eta 0:00:02
#    -------------------- ------------------- 0.7/1.5 MB 628.8 kB/s eta 0:00:02
#    -------------------- ------------------- 0.7/1.5 MB 637.8 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.5 MB 647.4 kB/s eta 0:00:02
#    ---------------------- ----------------- 0.8/1.5 MB 655.4 kB/s eta 0:00:01
#    ------------------------ --------------- 0.9/1.5 MB 663.4 kB/s eta 0:00:01
#    ------------------------- -------------- 0.9/1.5 MB 670.3 kB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 690.7 kB/s eta 0:00:01
#    ----------------------------- ---------- 1.1/1.5 MB 702.9 kB/s eta 0:00:01
#    ------------------------------ --------- 1.1/1.5 MB 708.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.2/1.5 MB 726.8 kB/s eta 0:00:01
#    --------------------------------- ------ 1.2/1.5 MB 730.5 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.2/1.5 MB 735.4 kB/s eta 0:00:01
#    ----------------------------------- ---- 1.3/1.5 MB 745.1 kB/s eta 0:00:01
#    ------------------------------------ --- 1.3/1.5 MB 754.8 kB/s eta 0:00:01
#    ------------------------------------- -- 1.4/1.5 MB 764.7 kB/s eta 0:00:01
#    -------------------------------------- - 1.4/1.5 MB 761.2 kB/s eta 0:00:01
#    ---------------------------------------  1.4/1.5 MB 764.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 744.1 kB/s eta 0:00:00
# Installing collected packages: lightgbm
# Successfully installed lightgbm-4.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# Gerekli kütüphaneleri içe aktarın
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import lightgbm as lgb
import matplotlib.pyplot as plt

# %%
# 1. CSV dosyasını yükleyin (dosya JupyterLab dizininde olmalıdır)
df = pd.read_csv("Interpolated_and_Predicted_Data.csv")

# 2. İlgili sıcaklık sütunlarının ortalamasını alarak yeni bir sütun oluşturun
temperature_columns = [
    "BRS.T35_T_GBX_OIL_1",
    "BRS.T35_T_GBX_OIL_2",
    "BRS.T35_T_GBX_T1_HSS",
    "BRS.T35_T_GBX_T1_IMS",
    "BRS.T35_T_GBX_T3_HSS",
    "BRS.T35_T_GBX_T3_IMS"
]

# %%
df["BRS.T35_T_GBX_Avg"] = df[temperature_columns].mean(axis=1)

# 3. Orijinal sıcaklık sütunlarını kaldırın
df = df.drop(columns=temperature_columns)

# 4. 'time' sütununu datetime formatına çevirin ve veriyi zaman sırasına göre sıralayın
df["time"] = pd.to_datetime(df["time"])
df = df.sort_values("time")

# 5. Veriyi zaman tabanlı olarak ayırın: İlk %75 eğitim, son %25 test
split_index = int(0.75 * len(df))
train_df = df.iloc[:split_index]
test_df = df.iloc[split_index:]

# 6. Modelleme için özellikler (X) ve hedef (y) belirleyin (time ve hedef sütunları hariç)
X_train = train_df.drop(columns=["time", "BRS.T35_T_GBX_Avg"])
y_train = train_df["BRS.T35_T_GBX_Avg"]

X_test = test_df.drop(columns=["time", "BRS.T35_T_GBX_Avg"])
y_test = test_df["BRS.T35_T_GBX_Avg"]

# 7. LightGBM modelini oluşturun ve eğitin
model = lgb.LGBMRegressor(random_state=42)
model.fit(X_train, y_train)

# 8. Test kümesi üzerinde tahmin yapın ve modeli değerlendirin
y_pred = model.predict(X_test)
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print("LightGBM Model Performansı (Test Kümesi):")
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
print("R2 Score:", r2)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000247 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 42768, number of used features: 6
# [LightGBM] [Info] Start training from score 52.929967
# LightGBM Model Performansı (Test Kümesi):
# Mean Absolute Error (MAE): 0.7198710331137642
# Root Mean Squared Error (RMSE): 1.102837886017084
# R2 Score: 0.9929113414585892
# C:\Users\90551\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# 9. Gerçek vs Tahmin Edilen Değerler Grafiği
plt.figure(figsize=(8,6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--', lw=2)
plt.xlabel("Gerçek Değerler")
plt.ylabel("Tahmin Edilen Değerler")
plt.title("Gerçek vs Tahmin Edilen Değerler (LightGBM)")
plt.show()

# 10. Hata (Residual) Grafiği
residuals = y_test - y_pred
plt.figure(figsize=(8,6))
plt.scatter(y_pred, residuals, alpha=0.6)
plt.axhline(0, color='r', linestyle='--')
plt.xlabel("Tahmin Edilen Değerler")
plt.ylabel("Hata (Residual)")
plt.title("Hata Dağılımı (Residual Plot)")
plt.show()

# %%
df.head()
# Out:
#                  time  BRS.T35_N_ROT_PLC  BRS.T35_Power  BRS.T35_T_GEAR_BEAR  \
# 0 2024-01-25 00:00:00          10.723178     544.650024            61.220001
# 1 2024-01-25 00:10:00          10.255564     420.470001            60.650002
# 2 2024-01-25 00:20:00          10.076803     404.429993            60.090000
# 3 2024-01-25 00:30:00           9.851302     344.700012            59.520000
# 4 2024-01-25 00:40:00           9.354575     157.369995            58.950001
#
#    BRS.T35_Temp_Ambient  BRS.T35_WIND_DIR  BRS.T35_Wind_speed  \
# 0                  5.00        101.000000                6.28
# 1                  4.09         93.879997                5.80
# 2                  5.00        103.050003                5.82
# 3                  5.00         96.570000                5.09
# 4                  5.00        104.849998                4.67
#
#    BRS.T35_T_GBX_Avg
# 0          57.030000
# 1          56.563334
# 2          56.116667
# 3          55.666667
# 4          55.216667

# %%
import pandas as pd
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Interpolated_and_Predicted_Data.csv")

# 2. İlgili sıcaklık sütunlarının ortalamasını alarak yeni bir sütun oluşturun
temperature_columns = [
    "BRS.T35_T_GBX_OIL_1",
    "BRS.T35_T_GBX_OIL_2",
    "BRS.T35_T_GBX_T1_HSS",
    "BRS.T35_T_GBX_T1_IMS",
    "BRS.T35_T_GBX_T3_HSS",
    "BRS.T35_T_GBX_T3_IMS"
]
df["BRS.T35_T_GBX_Avg"] = df[temperature_columns].mean(axis=1)

# 3. Orijinal sıcaklık sütunlarını kaldırın
df = df.drop(columns=temperature_columns)

# 4. 'time' sütununu datetime formatına çevirin ve veriyi zaman sırasına göre sıralayın
df["time"] = pd.to_datetime(df["time"])
df = df.sort_values("time")

# %%
# 5. Veriyi zamana göre ayırın: İlk %75 eğitim, son %25 test
split_index = int(0.75 * len(df))
train_df = df.iloc[:split_index]
test_df = df.iloc[split_index:]

# 6. Modelleme için özellikler (X) ve hedef (y) belirleyin. 'time' ve hedef sütunu modelden çıkarılır.
X_train = train_df.drop(columns=["time", "BRS.T35_T_GBX_Avg"])
y_train = train_df["BRS.T35_T_GBX_Avg"]

X_test = test_df.drop(columns=["time", "BRS.T35_T_GBX_Avg"])
y_test = test_df["BRS.T35_T_GBX_Avg"]

# 7. LightGBM modelini oluşturun ve eğitin
model = lgb.LGBMRegressor(random_state=42)
model.fit(X_train, y_train)
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001647 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1530
# [LightGBM] [Info] Number of data points in the train set: 42768, number of used features: 6
# [LightGBM] [Info] Start training from score 52.929967
# LGBMRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# 9. Model performans metriklerini hesaplayın
mae = mean_absolute_error(y_test, y_pred)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2 = r2_score(y_test, y_pred)

print("LightGBM Model Performansı (Test Kümesi):")
print("Mean Absolute Error (MAE):", mae)
print("Root Mean Squared Error (RMSE):", rmse)
print("R2 Score:", r2)
# Out:
# LightGBM Model Performansı (Test Kümesi):
# Mean Absolute Error (MAE): 0.7198710331137642
# Root Mean Squared Error (RMSE): 1.102837886017084
# R2 Score: 0.9929113414585892
# C:\Users\90551\anaconda3\Lib\site-packages\sklearn\metrics\_regression.py:483: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
plt.figure(figsize=(10,6))
plt.plot(test_df["time"], y_test, label="Gerçek VG Temp", marker="o")
plt.plot(test_df["time"], y_pred, label="Tahmin Edilen VG Temp", marker="x")
plt.xlabel("Zaman")
plt.ylabel("VG Temp (BRS.T35_T_GBX_Avg)")
plt.title("Zamana Göre Gerçek ve Tahmin Edilen VG Temp Değerleri")
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
